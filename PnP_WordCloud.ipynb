# %%
import pandas as pd
df = pd.read_csv("data/Questionaire_Responces.csv")
#print(df)

# %%
before_words = []
for a in df['Q5'].fillna(''):
    before_words = before_words + a.split()

before_words = [x.lower() for x in before_words]    

print(before_words)
#print(after_words)
# Out:
# ['patterns', 'methodology', 'being', 'curious', '"...', "you're", 'a', 'scientist"', '"...you', 'do', 'science"', '"...you', 'try', 'your', 'best', 'not', 'to', 'explode', 'things"', '"...doing', 'lab!', 'living', 'in', 'a', 'lab."', 'curiosity', 'curiosity', 'understanding', 'magic', 'curiosity', 'always', 'honesty.', 'passion.', 'joy.', 'thrill.', 'exploring', 'science-freak', 'curiosity', 'researching', 'desire', 'to', 'learn', 'and', 'discover', 'to', 'understand', 'our', 'environment', 'explaining', 'things,', 'surprising,', 'strange,', 'exciting', 'to', 'understand', 'our', 'environment', 'asking', 'why.', 'investigating', 'what', 'happens.', 'having', 'a', 'job', '-', 'future,', 'excellence,', 'being', 'curious', 'being', 'to', 'explain', 'the', 'world', 'around', 'use', 'using', 'evidence', 'being', 'a', 'better', 'person', 'curiosity', 'everything!', 'awesome!', 'investigating', 'investigating.', 'calculating.', 'acquiring.', 'solving.', 'fun', 'inquiring', 'learning', 'everything', 'finding', 'answers', 'to', 'unsolved', 'questions', 'or', 'problems', 'search', 'for', 'knowledge', 'every', 'day', 'exploration.', 'discovery.', 'investigation', '-', 'curiosity', 'finding', 'answers', 'to', 'questions', 'understanding', '(among', 'other', 'things)', 'that', 'such', 'a', 'sentence', "can't", 'be', 'readily', 'completed', 'in', 'one', 'word.', 'curiosity.', 'a', 'new', 'problem', 'to', 'solve', 'or', 'skill', 'to', 'learn', 'every', 'day.', 'discovering', 'hard', 'work', 'develop', 'interpretations', 'to', 'try', 'and', 'understand', 'the', 'universe', 'as', 'we', 'see', 'it,', 'and', 'keep', 'an', 'open', 'mind', 'because', 'we', 'will', 'be', 'wrong', 'a', 'lot!', 'always', 'more', 'to', 'learn...', '-', 'always', 'trying', 'to', 'understand', 'how', 'things', 'work', '-', 'doing', 'experiments', 'curiosity', 'work', 'thinking', 'creativity', 'detective', 'work', 'remembering', 'long', 'hours', 'fun', 'making', 'a', 'difference', 'making', 'a', 'mess', '-', 'curiosity', 'being', 'curious', 'about', 'the', 'world', 'and', 'using', 'the', 'scientific', 'method', 'trying', 'to', 'understand', 'it', '-', 'being', 'curious', 'seeing', 'the', 'world', 'in', 'different', 'way.', 'breakthroughs', 'discovering,', 'fun,', 'experiments,', 'enquiring', 'awesome', 'progress', 'exploring', 'our', 'world', 'and', 'asking', 'questions.', 'investigation', 'living', 'fun', 'wonder', '-', 'excitement', 'exploration', 'being', 'curious.', 'work', 'curiousity', '-', 'seeing', 'change', 'in', 'the', 'world.around', 'yiu', 'have', 'super', 'powers', 'being', 'cool', 'explore,', 'investigate,', 'try', 'to', 'understand', 'how', 'the', 'things', 'around', 'us', 'work', 'potential', 'enjoyinglearning', 'crazy....', 'reasonable', 'investigating', 'everything', '-', 'exploring', 'making', 'mistakes', 'finding', 'having', 'fun', 'experimenting', 'assuming', 'testing', 'proving', 'to', 'try', 'to', 'save', 'the', 'world', '-', 'no', 'less!', 'having', 'critical', 'thinking', 'truth-seeking', 'being', 'inquisitive', 'discovering', 'curiosity!', '(btw:', 'you', 'do', 'realise', 'you', 'are', 'asking', 'people', 'before', 'they', 'download', 'the', 'came', 'to', 'comment!)', 'discover', 'new', 'things', 'neutrons', ';)', 'questioning.', 'learning.', 'improvements', 'fun', 'limitless', 'excitement', 'lab', 'coats', 'everything', 'this', 'is', 'tricky', 'as', 'we', "haven't", 'played', 'the', 'game', 'yet,', 'this', 'was', 'a', 'prerequisite', 'to', 'download', 'the', 'game..', 'working', 'with', 'others', 'to', 'make', 'the', 'world', 'a', 'better', 'place.', 'exploring', 'everything', 'intelligence', 'money', 'imagination', 'trying', 'to', 'make', 'the', 'world', 'as', 'better', 'place', 'using', 'evidence', 'and', 'logic.', 'being', 'curious.', 'that', 'you', 'help', 'people', 'by', 'finding', 'things', 'that', 'help', 'others.', '-', 'is', 'a', 'state', 'of', 'mind,', 'not', 'a', 'profession', ':)', 'innovations', 'discovering', 'new', 'things', 'eve ...

# %%
import matplotlib.pyplot as plt

def plot_cloud(wordcloud):
    plt.figure(figsize=(40, 30))
    plt.imshow(wordcloud)
    plt.axis("off")

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np

x, y = np.ogrid[:3000, :3000]

mask = (x - 1500) ** 2 + (y - 1500) ** 2 > 1300 ** 2
mask = 255 * mask.astype(int)
mask = mask[::2,:]

wordcloud = WordCloud(width=3000,
                    height=2000,
                    random_state=1, 
                    background_color='white',
                    mask=mask,
                    colormap='viridis', 
                    collocations=False, 
                    stopwords=STOPWORDS)

wordcloud.generate(' '.join(before_words))

plot_cloud(wordcloud)

wordcloud.to_file("figures/PnP_words_before.png")
